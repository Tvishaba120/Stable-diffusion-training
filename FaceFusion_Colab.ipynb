# %% [markdown]
# <a href="https://colab.research.google.com/github/Tvishaba120/Stable-diffusion-training/blob/main/FaceFusion_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clone the FaceFusion repository
# !git clone https://github.com/facefusion/facefusion.git
# %cd /content/facefusion

# 2. Install Python dependencies
# !pip install -r requirements.txt

# 3. Install ONNX Runtime for CPU
# !pip install onnxruntime  # 👈 Use this instead of onnxruntime-gpu
# Out:
# Cloning into 'facefusion'...
# remote: Enumerating objects: 2694, done.
# remote: Counting objects: 100% (1255/1255), done.
# remote: Compressing objects: 100% (409/409), done.
# remote: Total 2694 (delta 1005), reused 849 (delta 846), pack-reused 1439 (from 2)
# Receiving objects: 100% (2694/2694), 21.54 MiB | 14.98 MiB/s, done.
# Resolving deltas: 100% (1786/1786), done.
# /content/facefusion
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 554.6 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 14.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 31.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 65.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 43.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 56.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install face_recognition opencv-python pillow numpy dlib --no-cache-dir
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.1/100.1 MB 120.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566166 sha256=649d50ae079fdc5b55410756357de894b465f0005ca8dacaa37e9d6137f0cf70
#   Stored in directory: /tmp/pip-ephem-wheel-cache-a136d6ic/wheels/04/52/ec/9355da79c29f160b038a20c784db2803c2f9fa2c8a462c176a
# Successfully built face-recognition-models
# ...

# %%
# !python run.py
# Out:
# python3: can't open file '/content/facefusion/run.py': [Errno 2] No such file or directory
